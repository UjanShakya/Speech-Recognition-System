# %%
import json
import numpy as np
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split

# %%
DATAPATH = "data.json"
SAVED_MODEL_PATH = "model.h5"
LEARNING_RATE = 0.0001
EPOCHS = 40
BATCH_SIZE = 32
NUM_KEYWORDS = 10

# %%
def load_dataset(datapath):
    
    with open(datapath, "r") as fp:
        data = json.load(fp)
        
    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    print("Training data loaded!")
    return X, y

def get_data_splits(datapath, test_size=0.1, validation_size=0.2):
    
    #load dataset
    X, y = load_dataset(datapath)
    
    #create train/validation/test splits
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train,test_size= validation_size)
    
    # convert inputs from 2d to 3d using nd array  #(num_segments, 13) -> (num_segments,13,1)
    X_train = X_train[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    
    return X_train, y_train, X_validation, y_validation,  X_test, y_test

# %%
def build_model(input_shape, learning_rate=0.0001, error="sparse_categorical_crossentropy"):
    
    #build network
    model = keras.Sequential()
    
    #1st conv layer
    model.add(keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=input_shape,
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'))
    
    #2nd conv layer
    model.add(keras.layers.Conv2D(32, (3,3), activation='relu',
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((3,3), strides=(2,2), padding='same'))
    
    #3rd conv layer
    model.add(keras.layers.Conv2D(32, (2,2), activation='relu',
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((2,2), strides=(2,2), padding='same'))
    
    #flatten output and fed into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))
    
    #softmax output layer
    model.add(keras.layers.Dense(10, activation='softmax')) #[0.1, 0.7, 0.2]
    
    
    #compile the model
    optimiser = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimiser, loss=error, metrics="accuracy")
    
    # print model
    model.summary()
    
    return model

# %%
 def main():
        
        #load train/validation data splits
        X_train, y_train, X_validation, y_validation, X_test, y_test = get_data_splits(DATAPATH)
        
        # build the CNN model
        input_shape = (X_train.shape[1], X_train.shape[2], 1)  #(num_segments, num_coeff, 1)
        model = build_model(input_shape, LEARNING_RATE)
        
        # train the model
        model.fit(X_train, y_train, epochs= EPOCHS, batch_size=BATCH_SIZE, validation_data=(X_validation, y_validation))
        
        #evaluate the model
        test_error, test_accuracy = model.evaluate(X_test, y_test)
        print(f"\nTest Error:{test_error}, Test Accuracy:{test_accuracy}")
        
        # save the model 
        model.save(SAVED_MODEL_PATH)

# %%
if __name__ == '__main__':
    main()
# Out:
# Training data loaded!
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 42, 11, 64)        640
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 42, 11, 64)        256
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 21, 6, 64)         0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 19, 4, 32)         18464
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 19, 4, 32)         128
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 10, 2, 32)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 9, 1, 32)          4128
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 9, 1, 32)          128
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 5, 1, 32)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                10304
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                650
# =================================================================
# Total params: 34,698
# Trainable params: 34,442
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 203/203 [==============================] - 4s 12ms/step - loss: 2.1249 - accuracy: 0.2958 - val_loss: 1.8703 - val_accuracy: 0.4327
# Epoch 2/40
# 203/203 [==============================] - 2s 11ms/step - loss: 1.4023 - accuracy: 0.5651 - val_loss: 1.1426 - val_accuracy: 0.7191
# Epoch 3/40
# 203/203 [==============================] - 2s 10ms/step - loss: 0.9978 - accuracy: 0.7168 - val_loss: 0.7528 - val_accuracy: 0.8340
# Epoch 4/40
# 203/203 [==============================] - 3s 13ms/step - loss: 0.7392 - accuracy: 0.8108 - val_loss: 0.5591 - val_accuracy: 0.8895
# Epoch 5/40
# 203/203 [==============================] - 4s 18ms/step - loss: 0.5580 - accuracy: 0.8660 - val_loss: 0.4255 - val_accuracy: 0.9191
# Epoch 6/40
# 203/203 [==============================] - 2s 11ms/step - loss: 0.4454 - accuracy: 0.9026 - val_loss: 0.3175 - val_accuracy: 0.9475
# Epoch 7/40
# 203/203 [==============================] - 2s 11ms/step - loss: 0.3601 - accuracy: 0.9270 - val_loss: 0.2823 - val_accuracy: 0.9580
# Epoch 8/40
# 203/203 [==============================] - 3s 14ms/step - loss: 0.3008 - accuracy: 0.9429 - val_loss: 0.2301 - val_accuracy: 0.9636
# Epoch 9/40
# 203/203 [==============================] - 3s 13ms/step - loss: 0.2595 - accuracy: 0.9511 - val_loss: 0.2054 - val_accuracy: 0.9710
# Epoch 10/40
# 203/203 [==============================] - 2s 11ms/step - loss: 0.2332 - accuracy: 0.9622 - val_loss: 0.1831 - val_accuracy: 0.9741
# Epoch 11/40
# 203/203 [==============================] - 3s 17ms/step - loss: 0.2049 - accuracy: 0.9642 - val_loss: 0.1618 - val_accuracy: 0.9796
# Epoch 12/40
# 203/203 [==============================] - 2s 12ms/step - loss: 0.1872 - accuracy: 0.9721 - val_loss: 0.1478 - val_accuracy: 0.9821
# Epoch 13/40
# 203/203 [==============================] - 3s 14ms/step - loss: 0.1642 - accuracy: 0.9792 - val_loss: 0.1454 - val_accuracy: 0.9833
# Epoch 14/40
# 203/203 [==============================] - 3s 12ms/step - loss: 0.1580 - accuracy: 0.9804 - val_loss: 0.1395 - val_accuracy: 0.9796
# Epoch 15/40
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1553 - accuracy: 0.9821 - val_loss: 0.1317 - val_accuracy: 0.9870
# Epoch 16/40
# 203/203 [==============================] - 3s 13ms/step - loss: 0.1329 - accuracy: 0.9861 - val_loss: 0.1422 - val_accuracy: 0.9790
# Epoch 17/40
# 203/203 [==============================] - 3s 15ms/step - loss: 0.1276 - accuracy: 0.9877 - val_loss: 0.1118 - val_accuracy: 0.9932
# Epoch 18/40
# 203/203 [==============================] - 3s 14ms/step - loss: 0.1194 - accuracy: 0.9907 - val_loss: 0.1133 - val_accuracy: 0.9914
# Epoch 19/40
# 203/203 [==============================] - 4s 21ms/step - loss: 0.1165 - accuracy: 0.9895 - val_loss: 0.1030 - val_accuracy: 0.9932
# Epoch 20/40
# 203/203 [==============================] - 3s 16ms/step - loss: 0.1113 - accuracy: 0.9914 - val_loss: 0.1068 - val_accuracy: 0.9889
# Epoch 21/40
# 203/203 [==============================] - 2s 12ms/step - loss: 0.1047 - accuracy: 0.9931 - val_loss: 0.0981 - val_accuracy: 0.9938
